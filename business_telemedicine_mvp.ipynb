# %% [markdown]
# #### Business Fundamentals | MVP
#
# # Expanding Telehealth to Offset Costs of Missed Appointments
#
# ## **Business Opportunity**
# The COVID-19 pandemic and Medicare's temporary [expansion of covered telehealth services](https://www.medicare.gov/coverage/telehealth) accelerated the adoption of patients meeting with their doctor via phone or video. While this was crucial during the pandemic to help people access care without needing to take public transportation and congregate in medical waiting rooms, it may have opened an opportunity for medical practices to avoid the costs associated with patients missing their medical appointments. Unused 60-minute time-slots cost medical practices `$` 200 on [average](https://www.hcinnovationgroup.com/clinical-it/article/13008175/missed-appointments-cost-the-us-healthcare-system-150b-each-year), costing the U.S. `$` 150 billion each year from missed appointments alone.
#
# ## **Solution Path**
# Exploratory data analysis to see how many Medicare patients over the age of 75 in metro areas used telehealth services during 2020 and 2021 to inform decisions about investing in telehealth technology.
#
# ## **Impact Hypothesis**
# Offering telehealth services to patients would reduce costs the medical practice incurs due to no-shows.
#
# ## **Measures of Success**
# * 15% cost reduction from missed appointments
# * 10% increase in appointment retainment
# * 15% increase in patient overall health due to continuity of care
#
# ## **Risks & Assumptions**
# Risks
#   * Telehealth services have hidden costs that do not offset the income lost to no-shows.
#   * Patients still need to overcome challenges that contribute to missed appointments if their doctor needs to see them in person
#   * The Medicare data does not represent the patient population of the client practice and is not generalizable.
#
# Assumptions
#   * Patients ages 75+ are more likely to live with one or more chronic conditions that impede their ability to get around on public transportation.
#   * Patients are interested in telemedicine if offered and have reliable internet at home to access it.
#   * Physicians can assess patients via telemedicine as well as in-person visits.
#
# ## **Data**
# The [Medicare Current Beneficiary Survey (MCBS)](https://mcbs.norc.org/us/en/mcbs.html) is an ongoing survey of people enrolled in Medicare. The survey's goals are to [collect information](https://www.cms.gov/Research-Statistics-Data-and-Systems/Downloadable-Public-Use-Files/MCBS-Public-Use-File) about access to care, satisfaction with care, and special topics. The data for this analysis (Winter 2021 survey) asked participants about access and use of telehealth services (video and audio), access to technology (internet at home, computers, smartphones, tablets), and use of video conferencing services (e.g., Zoom, Skype, FaceTime).
#
# For this analysis, I examined [data](https://docs.google.com/spreadsheets/d1q19flza3pA9hMvVWhorM9Fd_Ab_sUOuDrd_pE-l10kY/edit?usp=sharing) from respondents (n=1686) in the U.S. Northeast.
#
# ## **Preliminary Visualization**
# The pie charts show demographics, the percent of respondents who used telemedicine, and interactions between age and income among telemedicine users.
#
# ## **Preliminary Insight**
# Since November 2020, half of the respondents in the sample have used telemedicine. Of those who used telemedicine, the majority were aged 75 and above. Among respondents 75+, more respondents with incomes over $25,000 used telehealth services. The intended audience of this analysis (people 75+) uses telemedicine; however, income plays a role.

# %% [markdown]
# ![MCBS-logo.jpeg](attachment:MCBS-logo.jpeg)

# %% [markdown]
# # Survey Respondents' Demographics (n=1,686)
#
# * Northeast U.S.
# * Major cities: New York, Philadelphia, Boston, Pittsburgh

# %% [markdown]
# ![Respondents'%20Age.png](attachment:Respondents'%20Age.png)

# %% [markdown]
# ![Respondents'%20Income.png](attachment:Respondents'%20Income.png)

# %% [markdown]
# # Telemedicine Survey Responses

# %% [markdown]
# #### Since November 2020, have you had an appointment with a doctor or other health professional by telephone or video?
#
# ![Telemedicine%20Use.png](attachment:Telemedicine%20Use.png)

# %% [markdown]
# # Feature Interactions

# %% [markdown]
# #### Interaction of Age and Telemedicine Use
#
# ![Telemedicine%20Use%20by%20Age.png](attachment:Telemedicine%20Use%20by%20Age.png)

# %% [markdown]
# #### Interaction of Age, Income, and Telemedicine Use
#
# ![Telemedicine%20Users%20Aged%2075+%20by%20Income.png](attachment:Telemedicine%20Users%20Aged%2075+%20by%20Income.png)
